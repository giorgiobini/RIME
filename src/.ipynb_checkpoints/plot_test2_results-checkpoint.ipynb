# %%
its_jupyter_notebook = True

# %%
import pandas as pd
import os
import time
import numpy as np
import seaborn as sns
import pickle
import torch
from pathlib import Path
import matplotlib.pyplot as plt
import sys
from sklearn.metrics import classification_report, roc_curve, roc_auc_score

sys.path.insert(0, '..')

from config import *
from util.plot_utils import obtain_plot, plot_logs
if its_jupyter_notebook:
    sys.argv = [''] #Remove this if it's not a jupyter notebook!

# %%
checkpoint_dir = os.path.join(ROOT_DIR, 'checkpoints', 'binary_cl2')

# %%
file_train = os.path.join(rna_rna_files_dir, "gene_pairs_training_nt.txt")
with open(file_train, "rb") as fp:   # Unpickling
    gene_pairs_train = pickle.load(fp)
    
file_test = os.path.join(rna_rna_files_dir, "gene_pairs_test_nt.txt")
with open(file_test, "rb") as fp:   # Unpickling
    gene_pairs_test = pickle.load(fp)
    
file_test_subset = os.path.join(rna_rna_files_dir, "gene_pairs_test_sampled_nt.txt")
with open(file_test_subset, "rb") as fp:   # Unpickling
    gene_pairs_test_subset = pickle.load(fp)

# %%
res = pd.read_csv(os.path.join(checkpoint_dir, 'test_results.csv'))

print(classification_report(res.ground_truth, res.prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.65      0.69     24997
#            1       0.38      0.45      0.41     11525
#
#     accuracy                           0.59     36522
#    macro avg       0.55      0.55      0.55     36522
# weighted avg       0.61      0.59      0.60     36522

# %% [markdown]
# ### Roc Curve

# %%
res
# Out:
#        Unnamed: 0                                couples  gene1_pc  gene2_pc  \
# 0               0        ENSG00000113583_ENSG00000257315      True      True
# 1               1        ENSG00000113583_ENSG00000257315      True      True
# 2               2        ENSG00000113583_ENSG00000147400      True      True
# 3               3        ENSG00000113583_ENSG00000173320      True      True
# 4               4        ENSG00000113583_ENSG00000173320      True      True
# ...           ...                                    ...       ...       ...
# 36517       36517  ENSMUSG00000092622_ENSMUSG00000102777      True     False
# 36518       36518  ENSMUSG00000097093_ENSMUSG00000099717     False     False
# 36519       36519  ENSMUSG00000103345_ENSMUSG00000104950     False     False
# 36520       36520  ENSMUSG00000106025_ENSMUSG00000106186     False     False
# 36521       36521  ENSMUSG00000105416_ENSMUSG00000106186     False     False
#
#        original_length1  original_length2  \
# 0                  2188             12481
# 1                  2188             12481
# 2                  2188              1413
# 3                  2188             10507
# 4                  2188             10507
# ...                 ...               ...
# 36517              1681               576
# 36518               881               604
# 36519              6918              1946
# 36520              2362              2299
# 36521              1629              2299
#
#                                             id_sample  probability  \
# 0             ENSG00000113583_ENSG00000257315_easypos     0.489626
# 1             ENSG00000113583_ENSG00000257315_hardneg     0.489926
# 2             ENSG00000113583_ENSG00000147400_easypos     0.479551
# 3             ENSG00000113583_ENSG00000173320_easyneg     0.449810
# 4            ENSG00000113583_ENSG00000173320_smartneg     0.484801
# ...                                               ...          ...
# 36517  ENSMUSG00000092622_ENSMUSG00000102777_smartneg     0.473170
# 36518  ENSMUSG00000097093_ENSMUSG00000099717_smartneg     0.430512
# 36519  ENSMUSG00000103345_ENSMUSG00000104950_smartneg     0.328977
# 36520  ENSMUSG00000106025_ENSMUSG00000106186_smartneg     0.365400
# 36521  ENSMUSG00000105416_ENSMUSG00000106186_smartneg     0.241244
#
#        ground_truth                           g1                          g2  \
# 0                 1       ENSG00000113583_0_2188   ENSG00000257315_3670_9640
# 1                 0       ENSG00000113583_0_2188  ENSG00000257315_6325_12294
# 2                 1       ENSG00000113583_0_2188      ENSG00000147400_0_1413
# 3                 0       ENSG00000113583_0_2188   ENSG00000173320_1321_7290
# 4                 0       ENSG00000113583_0_2188    ENSG00000173320_299_6269
# ...             ...                          ...                         ...
# 36517             0    ENSMUSG00000092622_0_1681    ENSMUSG00000102777_0_576
# 36518             0     ENSMUSG00000097093_0_881    ENSMUSG00000099717_0_604
# 36519             0  ENSMUSG00000103345_378_6348   ENSMUSG00000104950_0_1946
# 36520             0    ENSMUSG00000106025_0_2362   ENSMUSG00000106186_0_2299
# 36521             0    ENSMUSG00000105416_0_1629   ENSMUSG00000106186_0_2299
#
#          policy  len_g1  len_g2  prediction  sampled_area    original_gene_id  \
# 0       easypos    2188    5970           0      13062360     ENSG00000113583
# 1       hardneg    2188    5969           0      13060172     ENSG00000113583
# 2       easypos    2188    1413           0       3091644     ENSG00000113583
# 3       easyneg    5969    2188           0      13060172     ENSG00000113583
# 4      smartneg    5970    2188           0      13062360     ENSG00000113583
# ...         ...     ...     ...         ...           ...                 ...
# 36517  smartneg    1681     576           0        968256  ENSMUSG00000092622
# 36518  smartneg     604     881           0        532124  ENSMUSG00000097093
# 36519  smartneg    1946    5970           0      11617620  ENSMUSG00000103345
# 36520  smartneg    2299    2362           0       5430238  ENSMUSG00000106025
# 36521  smartneg    2299    1629           0       3745071  ENSMUSG00000105416
#
#       specie      gene1_original      gene2_original
# 0      human     ENSG00000113583     ENSG00000257315
# 1      human     ENSG00000113583     ENSG00000257315
# 2      human     ENSG00000113583     ENSG00000147400
# 3      human     ENSG00000113583     ENSG00000173320
# 4      human     ENSG00000113583     ENSG00000173320
# ...      ...                 ...                 ...
# 36517  mouse  ENSMUSG00000092622  ENSMUSG00000102777
# 36518  mouse  ENSMUSG00000097093  ENSMUSG00000099717
# 36519  mouse  ENSMUSG00000103345  ENSMUSG00000104950
# 36520  mouse  ENSMUSG00000106025  ENSMUSG00000106186
# 36521  mouse  ENSMUSG00000105416  ENSMUSG00000106186
#
# [36522 rows x 20 columns]

# %%
fpr, tpr, _ = roc_curve(res.ground_truth,  res.probability)
auc = roc_auc_score(res.ground_truth,  res.probability)

#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # PLOTS

# %% [markdown]
# ### Log plots

# %%
log = pd.read_json(Path(os.path.join(checkpoint_dir, 'log.txt')), lines=True)
best_model = np.argmax(log.test_accuracy)
for metric in ['loss', 'accuracy']:
    plot_logs(log, metric, best_model = best_model)

# %% [markdown]
# ## Metrics

# %%
print(res.prediction.value_counts())
print('\n')
print(res.ground_truth.value_counts())
# Out:
# 0    22670
# 1    13852
# Name: prediction, dtype: int64
#
#
# 0    24997
# 1    11525
# Name: ground_truth, dtype: int64

# %%
n_conf = 10

# %%
obtain_plot(res, n_original_df = res.shape[0], title = 'Metrics', n_conf = n_conf)

# %%
human = res[(res.specie == 'human')]
obtain_plot(human, n_original_df = res.shape[0], title = f'Metrics: Human ', n_conf = n_conf)

# %%
mouse = res[(res.specie == 'mouse')]
obtain_plot(mouse, n_original_df = res.shape[0], title = f'Metrics: Mouse ', n_conf = n_conf)

# %%
full_length = res[(res.original_length1 <= MAX_RNA_SIZE)&(res.original_length2 <= MAX_RNA_SIZE)]
obtain_plot(full_length, n_original_df = res.shape[0], title = f'Metrics: Full length', n_conf = 10)

# %%
confidence_level = 0.66
high_conf_fl = full_length[(full_length.probability>confidence_level)|(full_length.probability<(1-confidence_level))]

# %%
(high_conf_fl.ground_truth == high_conf_fl.prediction).sum() / high_conf_fl.shape[0]
# Out:
# 0.6490566037735849

# %%
confidence_level = 0.65
high_conf_fl = full_length[(full_length.probability>confidence_level)|(full_length.probability<(1-confidence_level))]
obtain_plot(high_conf_fl, n_original_df = res.shape[0], title = f'Metrics: Full length (high confidence)', n_conf = n_conf)

# %%
big_area_size = res.sampled_area.quantile(0.9)
big_area_size = 5000**2
big_area = res[res['sampled_area'] > big_area_size]

obtain_plot(big_area, n_original_df = res.shape[0], title = f'Metrics: Big area', n_conf = n_conf)

# %%
no_pc = res[(res['gene1_pc'] == False)|(res['gene2_pc'] == False)]

obtain_plot(no_pc, n_original_df = res.shape[0], title = f'Metrics: At least one is no protein coding', n_conf = n_conf)

# %%
test = pd.read_csv(os.path.join(metadata_dir, f'test_sampled.csv'))[['id_gene1_sample', 'id_gene2_sample']]

# %%
test
# Out:
#                     id_gene1_sample                id_gene2_sample
# 0            ENSG00000115419_0_4840         ENSG00000000003_0_3796
# 1            ENSG00000142556_0_4628         ENSG00000000003_0_3796
# 2          ENSG00000000457_128_6098       ENSG00000009954_125_6095
# 3            ENSG00000000457_7_5977       ENSG00000111371_795_6765
# 4          ENSG00000000457_149_6119         ENSG00000113369_0_4239
# ...                             ...                            ...
# 29133   ENSMUSG00000069833_742_6712   ENSMUSG00000071531_1602_7572
# 29134  ENSMUSG00000069833_1365_7335   ENSMUSG00000078515_1976_7946
# 29135  ENSMUSG00000078515_3258_9228   ENSMUSG00000069833_1961_7931
# 29136  ENSMUSG00000078515_2246_8216  ENSMUSG00000069833_4128_10098
# 29137  ENSMUSG00000069833_1366_7336   ENSMUSG00000078515_2570_8540
#
# [29138 rows x 2 columns]

# %%
res1 = res.merge(test, left_on = ['g1', 'g2'], right_on = ['id_gene1_sample', 'id_gene2_sample']).ground_truth.value_counts()
res2 = res.merge(test, left_on = ['g1', 'g2'], right_on = ['id_gene2_sample', 'id_gene1_sample']).ground_truth.value_counts()

# %%
easypos_smartneg = p
easypos_smartneg.ground_truth.value_counts()
# Out:
# 0    5952
# 1    5760
# Name: ground_truth, dtype: int64

# %%
test_sampled = list(test.couples + '_' + test.policy + test.x1 + )

# %%
df_nt[df_nt.couples.isin(real_test_list)].interacting.value_counts()
# Out:
# False    16243
# True     14565
# Name: interacting, dtype: int64

# %%
res
# Out:
#        Unnamed: 0                                couples  gene1_pc  gene2_pc  \
# 0               0        ENSG00000113583_ENSG00000257315      True      True
# 1               1        ENSG00000113583_ENSG00000257315      True      True
# 2               2        ENSG00000113583_ENSG00000147400      True      True
# 3               3        ENSG00000113583_ENSG00000173320      True      True
# 4               4        ENSG00000113583_ENSG00000173320      True      True
# ...           ...                                    ...       ...       ...
# 36517       36517  ENSMUSG00000092622_ENSMUSG00000102777      True     False
# 36518       36518  ENSMUSG00000097093_ENSMUSG00000099717     False     False
# 36519       36519  ENSMUSG00000103345_ENSMUSG00000104950     False     False
# 36520       36520  ENSMUSG00000106025_ENSMUSG00000106186     False     False
# 36521       36521  ENSMUSG00000105416_ENSMUSG00000106186     False     False
#
#        original_length1  original_length2  \
# 0                  2188             12481
# 1                  2188             12481
# 2                  2188              1413
# 3                  2188             10507
# 4                  2188             10507
# ...                 ...               ...
# 36517              1681               576
# 36518               881               604
# 36519              6918              1946
# 36520              2362              2299
# 36521              1629              2299
#
#                                             id_sample  probability  \
# 0             ENSG00000113583_ENSG00000257315_easypos     0.489626
# 1             ENSG00000113583_ENSG00000257315_hardneg     0.489926
# 2             ENSG00000113583_ENSG00000147400_easypos     0.479551
# 3             ENSG00000113583_ENSG00000173320_easyneg     0.449810
# 4            ENSG00000113583_ENSG00000173320_smartneg     0.484801
# ...                                               ...          ...
# 36517  ENSMUSG00000092622_ENSMUSG00000102777_smartneg     0.473170
# 36518  ENSMUSG00000097093_ENSMUSG00000099717_smartneg     0.430512
# 36519  ENSMUSG00000103345_ENSMUSG00000104950_smartneg     0.328977
# 36520  ENSMUSG00000106025_ENSMUSG00000106186_smartneg     0.365400
# 36521  ENSMUSG00000105416_ENSMUSG00000106186_smartneg     0.241244
#
#        ground_truth                           g1                          g2  \
# 0                 1       ENSG00000113583_0_2188   ENSG00000257315_3670_9640
# 1                 0       ENSG00000113583_0_2188  ENSG00000257315_6325_12294
# 2                 1       ENSG00000113583_0_2188      ENSG00000147400_0_1413
# 3                 0       ENSG00000113583_0_2188   ENSG00000173320_1321_7290
# 4                 0       ENSG00000113583_0_2188    ENSG00000173320_299_6269
# ...             ...                          ...                         ...
# 36517             0    ENSMUSG00000092622_0_1681    ENSMUSG00000102777_0_576
# 36518             0     ENSMUSG00000097093_0_881    ENSMUSG00000099717_0_604
# 36519             0  ENSMUSG00000103345_378_6348   ENSMUSG00000104950_0_1946
# 36520             0    ENSMUSG00000106025_0_2362   ENSMUSG00000106186_0_2299
# 36521             0    ENSMUSG00000105416_0_1629   ENSMUSG00000106186_0_2299
#
#          policy  len_g1  len_g2  prediction  sampled_area    original_gene_id  \
# 0       easypos    2188    5970           0      13062360     ENSG00000113583
# 1       hardneg    2188    5969           0      13060172     ENSG00000113583
# 2       easypos    2188    1413           0       3091644     ENSG00000113583
# 3       easyneg    5969    2188           0      13060172     ENSG00000113583
# 4      smartneg    5970    2188           0      13062360     ENSG00000113583
# ...         ...     ...     ...         ...           ...                 ...
# 36517  smartneg    1681     576           0        968256  ENSMUSG00000092622
# 36518  smartneg     604     881           0        532124  ENSMUSG00000097093
# 36519  smartneg    1946    5970           0      11617620  ENSMUSG00000103345
# 36520  smartneg    2299    2362           0       5430238  ENSMUSG00000106025
# 36521  smartneg    2299    1629           0       3745071  ENSMUSG00000105416
#
#       specie      gene1_original      gene2_original
# 0      human     ENSG00000113583     ENSG00000257315
# 1      human     ENSG00000113583     ENSG00000257315
# 2      human     ENSG00000113583     ENSG00000147400
# 3      human     ENSG00000113583     ENSG00000173320
# 4      human     ENSG00000113583     ENSG00000173320
# ...      ...                 ...                 ...
# 36517  mouse  ENSMUSG00000092622  ENSMUSG00000102777
# 36518  mouse  ENSMUSG00000097093  ENSMUSG00000099717
# 36519  mouse  ENSMUSG00000103345  ENSMUSG00000104950
# 36520  mouse  ENSMUSG00000106025  ENSMUSG00000106186
# 36521  mouse  ENSMUSG00000105416  ENSMUSG00000106186
#
# [36522 rows x 20 columns]

# %%
subset_test_nt_sampled = os.path.join(rna_rna_files_dir, f"gene_pairs_test_sampled_nt.txt")
with open(subset_test_nt_sampled, "rb") as fp:  # Unpickling
    subset_test_nt_sampled = pickle.load(fp)
    
easypos_smartneg = res[res.id_sample.isin(subset_test_nt_sampled)]

# %%
easypos_smartneg.ground_truth.value_counts()
# Out:
# 0    12660
# 1    11525
# Name: ground_truth, dtype: int64

# %%
df_nt = pd.read_csv(os.path.join(metadata_dir, f'df_nt.csv'))
# Out:
# /tmp/ipykernel_226433/979959890.py:1: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_nt = pd.read_csv(os.path.join(metadata_dir, f'df_nt.csv'))

# %%
df_nt[df_nt.couples.isin(subset_test_nt_sampled)].interacting.value_counts()
# Out:
# False    16243
# True     14565
# Name: interacting, dtype: int64

# %%
easypos_smartneg = res[(res.policy == 'easypos')|(res.policy == 'smartneg')]

subset_test_nt_sampled = os.path.join(rna_rna_files_dir, f"gene_pairs_test_sampled_nt.txt")
with open(subset_test_nt_sampled, "rb") as fp:  # Unpickling
    subset_test_nt_sampled = pickle.load(fp)
    
easypos_smartneg = res[res.id_sample.isin(subset_test_nt_sampled)]


vc = easypos_smartneg.ground_truth.value_counts()
assert vc.loc[1] > vc.loc[0]
n_to_exclude = vc.loc[1] - vc.loc[0]
easypos_gt = easypos_smartneg[easypos_smartneg.ground_truth==1]
id_to_exclude = list(easypos_gt.sample(frac = 1).head(n_to_exclude).id_sample)
easypos_smartneg_sampled = easypos_smartneg[~easypos_smartneg.id_sample.isin(id_to_exclude)]
print((easypos_smartneg_sampled.prediction == easypos_smartneg_sampled.ground_truth).sum()/easypos_smartneg_sampled.shape[0])
obtain_plot(easypos_smartneg_sampled, n_original_df = res.shape[0], title = f'Metrics: recall is the accuracy of easypos, specificity is the accuracy of smartneg ', n_conf = n_conf)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[21], line 3
#       1 easypos_smartneg = res[(res.policy == 'easypos')|(res.policy == 'smartneg')]
#       2 vc = easypos_smartneg.ground_truth.value_counts()
# ----> 3 assert vc.loc[1] > vc.loc[0]
#       4 n_to_exclude = vc.loc[1] - vc.loc[0]
#       5 easypos_gt = easypos_smartneg[easypos_smartneg.ground_truth==1]
#
# AssertionError:

# %%
hn = res[(res.policy == 'hardneg')]
print(hn[hn.ground_truth == hn.prediction].shape[0]/hn.shape[0])

obtain_plot(hn, n_original_df = res.shape[0], title = f'Metrics:  specificity is the accuracy of hardneg ', n_conf = n_conf)
# Out:
# 0.609375

# %%
easy = res[(res.policy == 'easyneg')]
print(easy[easy.ground_truth == easy.prediction].shape[0]/easy.shape[0])

obtain_plot(easy, n_original_df = res.shape[0], title = f'Metrics: specificity is the accuracy of easyneg ', n_conf = n_conf)
# Out:
# 0.7066246056782335

# %%
df_train = pd.DataFrame({'couples':gene_pairs_train})
regex = df_train['couples'].str.extractall('(.*)_(.*)_(.*)').reset_index()
df_train['g1'] = regex[0]
df_train['g2'] = regex[1]
df_train_genes = set(df_train['g1']).union(set(df_train['g2']))

not_in_train = res[~(res.gene1_original.isin(df_train_genes) | res.gene2_original.isin(df_train_genes))]

obtain_plot(not_in_train, n_original_df = res.shape[0], title = f'Metrics: Genes not in training', n_conf = n_conf)

# %%
not_in_train_fl = not_in_train[(not_in_train.original_length1 <= MAX_RNA_SIZE)&(not_in_train.original_length2 <= MAX_RNA_SIZE)]
not_in_train_fl = not_in_train_fl[(not_in_train_fl.policy == 'easypos')|(not_in_train_fl.policy == 'smartneg')]
obtain_plot(not_in_train_fl, n_original_df = res.shape[0], title = f'Metrics: Genes not in training full length', n_conf = 8)

# %%
no_pc_no_train = not_in_train[(not_in_train['gene1_pc'] == False)|(not_in_train['gene2_pc'] == False)]

obtain_plot(no_pc_no_train, n_original_df = res.shape[0], title = f'Metrics: Genes not in training and at least one is no protein coding', n_conf = 8)

# %%
confidence_level = 0.6

no_pc_no_train = not_in_train[(not_in_train['gene1_pc'] == False)|(not_in_train['gene2_pc'] == False)]
no_pc_no_train = no_pc_no_train[(no_pc_no_train.probability>confidence_level)|(no_pc_no_train.probability<(1-confidence_level))]
no_pc_no_train = no_pc_no_train[(no_pc_no_train.policy == 'easypos')|(no_pc_no_train.policy == 'smartneg')]
obtain_plot(no_pc_no_train, n_original_df = res.shape[0], title = f'Metrics: Genes not in training and at least one is no protein coding, high confidence, easyposVSsmarneg ', n_conf = 15, excluding_treshold = 0.2)

# %%
confidence_level = 0.8
high_prob_pairs = res[(res.probability>confidence_level)|(res.probability<(1-confidence_level))]
high_prob_pairs = high_prob_pairs[(high_prob_pairs.policy == 'easypos')|(high_prob_pairs.policy == 'smartneg')]

obtain_plot(high_prob_pairs, n_original_df = res.shape[0], title = f'Metrics: The model is very confident (easypos VS smartneg) ', n_conf = n_conf)

# %%
confidence_level = 0.8
high_prob_pairs = not_in_train[(not_in_train.probability>confidence_level)|(not_in_train.probability<(1-confidence_level))]
high_prob_pairs = high_prob_pairs[(high_prob_pairs.policy == 'easypos')|(high_prob_pairs.policy == 'smartneg')]

obtain_plot(high_prob_pairs, n_original_df = res.shape[0], title = f'Metrics: The model is very confident (easypos VS smartneg) and genes are not in training ', n_conf = n_conf)

# %%
sns.kdeplot(list(pd.concat([easypos_smartneg.len_g1, easypos_smartneg.len_g2], axis = 0)), color = 'red', label = 'dataset')
sns.kdeplot(list(pd.concat([high_prob_pairs.len_g1, high_prob_pairs.len_g2], axis = 0)), color = 'blue', label = 'high_confidence_pair')
plt.title(f'Length distribution')
plt.legend()
